# %%
import os
import pandas as pd

# %%
def directory_to_dataframe(root_dir):
    file_data = []

    for root, dirs, files in os.walk(root_dir):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                relative_path = os.path.relpath(file_path, root_dir)

                dir_path = os.path.dirname(relative_path)

                with open(file_path, 'r') as f:
                    file_text = f.read()

                # Append the file data to the list
                file_data.append({
                    'filename': file,
                    'path': dir_path,
                    'file_text': file_text,
                    'combined': f'Title: {file} Content: {file_text}'
                })

    return pd.DataFrame(file_data)

# %%
files_df = directory_to_dataframe('anthonys-second-brain')
files_df
# Out:
#                                  filename                  path  \
# 0                 Welcome in my mind 🧠.md
# 1                               README.md
# 2                         Contact me 💌.md
# 3        Create a programming language.md  Programming language
# 4                Programming languages.md  Programming language
# ..                                    ...                   ...
# 589  Multitasking is counterproductive.md          Productivity
# 590                     Growth mindset.md          Productivity
# 591                 Social media detox.md          Productivity
# 592                Thinking in writing.md          Productivity
# 593                      Ego depletion.md          Productivity
#
#                                              file_text  \
# 0    ## Who I am?\n\nI'm **Anthony**, a `Date.today...
# 1    *You'll have a better browsing experience of t...
# 2    ## Want to get in touch? 😊\n\nI'd love to hear...
# 3    I've recently viewed this amazing conference "...
# 4    No need to say that programming is one of my f...
# ..                                                 ...
# 589  ---\nalias: "Multitasking"\n---\n\n## Why mult...
# 590  ## Growth vs. fixed mindset\nOpposed to the Fi...
# 591  ---\nalias: "Digital detox"\ntags:\n- "#produc...
# 592  ---\nalias: "Externalizing thoughts"\n---\n## ...
# 593  ## What is ego depletion?\n\nEgo depletion ref...
#
#                                               combined
# 0    Title: Welcome in my mind 🧠.md Content: ## Who...
# 1    Title: README.md Content: *You'll have a bette...
# 2    Title: Contact me 💌.md Content: ## Want to get...
# 3    Title: Create a programming language.md Conten...
# 4    Title: Programming languages.md Content: No ne...
# ..                                                 ...
# 589  Title: Multitasking is counterproductive.md Co...
# 590  Title: Growth mindset.md Content: ## Growth vs...
# 591  Title: Social media detox.md Content: ---\nali...
# 592  Title: Thinking in writing.md Content: ---\nal...
# 593  Title: Ego depletion.md Content: ## What is eg...
#
# [594 rows x 4 columns]

# %%
with open('output.txt', 'w') as f:
    f.write(files_df.iloc[0].combined.replace('\n', '\\n'))
